# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker


fig, ax = plt.subplots()
ax.grid(True)

ax.get_xaxis().get_major_formatter().set_useOffset(False)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
head = ["algorithm", "size", "min", "max", "avg" ]
df = pd.read_csv('./src/output/records.dat')

df = df.sort_values(by='size')
insertion= df[df.algorithm=='insertion'].query('avg >= 0')
quick = df[df.algorithm=='quick'].query('avg >= 0').drop_duplicates('size')
merge = df[df.algorithm=='merge'].query('avg >= 0').drop_duplicates('size')
heap = df[df.algorithm=='heap'].query('avg >= 0').drop_duplicates('size')
selection = df[df.algorithm=='selection'].query('avg >= 0')
tim = df[df.algorithm=='tim'].query('avg >= 0')
#plt.figure(figsize=(20,10))
plt.plot('size' , 'avg', data=insertion,label="insertion" )
plt.plot( 'size',  'avg', data=selection,label="selection")
plt.plot( 'size',  'avg', data=merge,label="merge")
plt.plot( 'size',  'avg', data=heap,label="heap")
plt.plot('size',  'avg', data=quick,label="quick")
plt.plot('size',  'avg', data=tim,label="tim")
plt.rcParams["figure.figsize"] = [20,10]
plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
#plt.xticks([str(int(i)) for i in quick['size']])

plt.title("Tempo de ordenação", fontsize=16, fontweight='bold')
plt.plot(usevlines=True,normed=True, maxlags=20,rotation = 45)

plt.legend()
plt.savefig('./imgs/all.png',transparent=False)

# %%
fig, ax = plt.subplots()
ax.grid(True)
plt.plot('size' , 'avg', data=insertion,label="avg")
plt.plot('size' , 'max', data=insertion,label="max")
plt.plot('size' , 'min', data=insertion,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação", fontsize=16, fontweight='bold')
plt.show()
fig.savefig('./imgs/all2.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=quick,label="avg")
plt.plot('size' , 'max', data=quick,label="max")
plt.plot('size' , 'min', data=quick,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/quick.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=merge,label="avg")
plt.plot('size' , 'max', data=merge,label="max")
plt.plot('size' , 'min', data=merge,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/merge.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=heap,label="avg")
plt.plot('size' , 'max', data=heap,label="max")
plt.plot('size' , 'min', data=heap,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/heap.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=selection,label="avg")
plt.plot('size' , 'max', data=selection,label="max")
plt.plot('size' , 'min', data=selection,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/selection.png',transparent=False)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df)
# Out:
#      algorithm       size         min         max         avg
# 0        merge       10.0    0.000109    0.000196    0.000134
# 1        quick       10.0    0.000128    0.000259    0.000159
# 2         heap       10.0    0.000110    0.000131    0.000115
# 3    insertion       10.0    0.000099    0.000105    0.000101
# 4    selection       10.0    0.000104    0.000109    0.000107
# 103        tim       10.0    0.000328    0.003273    0.000954
# 24       quick       25.0    0.015427    0.015439    0.015435
# 25        heap       25.0    0.015433    0.015438    0.015436
# 26   insertion       25.0    0.015427    0.015440    0.015433
# 27   selection       25.0    0.015435    0.015440    0.015436
# 23       merge       25.0    0.015403    0.015438    0.015429
# 109        tim       25.0    0.000094    0.000165    0.000131
# 115        tim       50.0    0.000156    0.000242    0.000207
# 50        heap       50.0    0.030688    2.374072    0.666358
# 51   insertion       50.0    0.030662    0.224231    0.114218
# 52   selection       50.0    0.071490    2.058100    0.653178
# 49       quick       50.0    0.010319    3.234662    0.707139
# 48       merge       50.0    0.010277    0.290413    0.139669
# 121        tim       75.0    0.000182    0.000281    0.000239
# 73       merge       75.0    0.045993    2.980240    0.684730
# 74       quick       75.0    0.045975    0.540117    0.178431
# 75        heap       75.0    0.045988    3.423312    0.737741
# 76   insertion       75.0    0.030654    2.257870    0.577956
# 77   selection       75.0    0.061221    3.082258    0.677682
# 104        tim      100.0    0.000943    0.001412    0.001069
# 5        merge      100.0    0.000244    0.000284    0.000257
# 7         heap      100.0    0.000361    0.000408    0.000389
# 8    insertion      100.0    0.000535    0.000576    0.000562
# 6        quick      100.0    0.000250    0.000300    0.000282
# 9    selection      100.0    0.000865    0.000971    0.000922
# 28       merge      250.0    0.010359    0.015471    0.014434
# 29       quick      250.0    0.015453    0.015482    0.015468
# 30        heap      250.0    0.015435    0.015463    0.015453
# 31   insertion      250.0    0.010345    0.015461    0.013403
# 32   selection      250.0    0.015462    0.015475    0.015467
# 110        tim      250.0    0.000496    0.000576    0.000535
# 55        heap      500.0    0.025557    0.336392    0.140745
# 57   selection      500.0    0.086106    0.728814    0.265962
# 54       quick      500.0    0.025544    0.845692    0.314892
# 116        tim      500.0    0.001079    0.001155    0.001115
# 56   insertion      500.0    0.045931    2.532024    0.563549
# 53       merge      500.0    0.010288    1.299162    0.452448
# 122        tim      750.0    0.001713    0.001808    0.001759
# 78       merge      750.0    0.056030    3.035997    0.726421
# 81   insertion      750.0    0.051613    1.238936    0.291314
# 80        heap      750.0    0.071298    0.407624    0.192575
# 79       quick      750.0    0.086663    0.285345    0.150890
# 82   selection      750.0    0.086171    2.324217    0.906894
# 10       merge     1000.0    0.002120    0.002186    0.002147
# 12        heap     1000.0    0.004220    0.004328    0.004271
# 105        tim     1000.0    0.002816    0.010674    0.005756
# 13   insertion     1000.0    0.049805    0.050164    0.050001
# 14   selection     1000.0    0.081908    0.083852    0.082724
# 11       quick     1000.0    0.002509    0.002556    0.002532
# 34       quick     2500.0    0.020492    0.020533    0.020520
# 33       merge     2500.0    0.016308    0.020555    0.019674
# 35        heap     2500.0    0.030666    0.030712    0.030692
# 37   selection     2500.0    1.040866    1.057464    1.051184
# 36   insertion     2500.0    0.655469    0.705415    0.679362
# 111        tim     2500.0    0.006724    0.015270    0.009879
# 62   selection     5000.0    4.389349   11.071403    7.876509
# 59       quick     5000.0    0.132596    1.049472    0.572789
# 60        heap     5000.0    0.071456    1.459438    0.554838
# 58       merge     5000.0    0.056138    0.575905    0.317067
# 117        tim     5000.0    0.014508    0.021873    0.017299
# 61   insertion     5000.0    3.119666    4.488955    3.421338
# 85        heap     7500.0    0.091783    2.433175    0.761382
# 86   insertion     7500.0    9.950216   17.755849   14.956718
# 87   selection     7500.0   12.111672   25.940890   18.310283
# 84       quick     7500.0    0.046002    0.901190    0.628663
# 83       merge     7500.0    0.040889    3.200166    0.958546
# 123        tim     7500.0    0.021352    0.022513    0.021746
# 19   selection    10000.0    8.436806    8.517385    8.485919
# 18   insertion    10000.0    5.570757    5.594643    5.580801
# 17        heap    10000.0    0.058951    0.059606    0.059217
# 16       quick    10000.0    0.037879    0.038875    0.038224
# 15       merge    10000.0    0.026876    0.027686    0.027159
# 106        tim    10000.0    0.034101    0.037400    0.035464
# 112        tim    25000.0    0.111152    0.114437    0.113078
# 41   insertion    25000.0  100.007185  101.100386  100.470021
# 40        heap    25000.0    0.386802    0.398490    0.392309
# 39       quick    25000.0    0.207652    0.221313    0.214573
# 38       merge    25000.0    0.159023    0.180067    0.170371
# 42   selection    25000.0   55.492167  137.037723   96.678016
# 118        tim    50000.0    0.258068    0.264875    0.261579
# 63       merge    50000.0    0.367973    1.362631    0.715105
# 66   insertion    50000.0  695.878417  788.625699  736.921862
# 65        heap    50000.0    0.905054    3.950917    2.696842
# 64       quick    50000.0    0.543042    2.960150    1.089455
# 67   selection    50000.0   -1.000000   -1.000000   -1.000000
# 90        heap    75000.0    1.461277    9.623766    4.747035
# 88       merge    75000.0    0.602935    3.018861    1.164467
# 124        tim    75000.0    0.394261    0.398281    0.396597
# 89       quick    75000.0    0.959620    3.666916    2.054050
# 20       merge   100000.0    0.392965    0.396802    0.395298
# 21       quick   100000.0    0.620012    0.643191    0.629551
# 22        heap   100000.0    0.929068    0.943448    0.938081
# 107        tim   100000.0    0.550456    0.755100    0.594023
# 44       quick   250000.0    1.744236    1.764935    1.748910
# 45        heap   250000.0    2.700012    2.713338    2.707884
# 46   insertion   250000.0   -1.000000   -1.000000   -1.000000
# 113        tim   250000.0    1.540668    1.561111    1.549900
# 47   selection   250000.0   -1.000000   -1.000000   -1.000000
# 43       merge   250000.0    1.119463    1.130125    1.125397
# 119        tim   500000.0    3.388183    3.413103    3.400416
# 72   selection   500000.0   -1.000000   -1.000000   -1.000000
# 71   insertion   500000.0   -1.000000   -1.000000   -1.000000
# 69       quick   500000.0    8.793435   18.131779   14.590731
# 70        heap   500000.0    6.156114    6.221870    6.186547
# 68       merge   500000.0    5.215955   25.519435   10.882425
# 91       merge   750000.0   10.413586   18.620404   13.859352
# 125        tim   750000.0    5.131883    5.177497    5.157555
# 92        heap   750000.0    9.929854   10.232592   10.040222
# 93       quick   750000.0    7.023986    7.101732    7.057057
# 108        tim  1000000.0    7.294288    7.498722    7.352870
# 114        tim  2500000.0   20.953641   21.069360   21.012376
# 96       merge  2500000.0   15.052354   15.193976   15.130788
# 95        heap  2500000.0   37.347842   37.653683   37.548091
# 94       quick  2500000.0   27.127193   27.809839   27.489411
# 120        tim  5000000.0   43.918163   45.421295   44.616345
# 97       quick  5000000.0   63.061707   63.344349   63.201582
# 99       merge  5000000.0   32.565872   32.655394   32.602340
# 98        heap  5000000.0   81.373805   81.538803   81.436634
# 100      quick  7500000.0  100.154283  101.615142  100.636710
# 101       heap  7500000.0  127.912392  128.181206  128.055626
# 102      merge  7500000.0   51.072981   52.246640   51.373616
# 126        tim  7500000.0   65.050415   67.818444   66.087821
