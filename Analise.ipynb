# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker


fig, ax = plt.subplots()
ax.grid(True)

ax.get_xaxis().get_major_formatter().set_useOffset(False)
ax.get_yaxis().get_major_formatter().set_useOffset(False)
head = ["algorithm", "size", "min", "max", "avg" ]
df = pd.read_csv('./src/output/records.dat')

df = df.sort_values(by='size')
insertion= df[df.algorithm=='insertion'].query('avg >= 0')
quick = df[df.algorithm=='quick'].query('avg >= 0').drop_duplicates('size')
merge = df[df.algorithm=='merge'].query('avg >= 0').drop_duplicates('size')
heap = df[df.algorithm=='heap'].query('avg >= 0').drop_duplicates('size')
selection = df[df.algorithm=='selection'].query('avg >= 0')
tim = df[df.algorithm=='tim'].query('avg >= 0')
intro = df[df.algorithm=='intro'].query('avg >= 0')
#plt.figure(figsize=(20,10))
plt.plot('size' , 'avg', data=insertion,label="insertion" )
plt.plot( 'size',  'avg', data=selection,label="selection")
plt.plot( 'size',  'avg', data=merge,label="merge")
plt.plot( 'size',  'avg', data=heap,label="heap")
plt.plot('size',  'avg', data=quick,label="quick")
plt.plot('size',  'avg', data=tim,label="tim")

plt.plot('size',  'avg', data=intro,label="intro")
plt.rcParams["figure.figsize"] = [20,10]
plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
#plt.xticks([str(int(i)) for i in quick['size']])

plt.title("Tempo de ordenação comparativo", fontsize=16, fontweight='bold')
plt.plot(usevlines=True,normed=True, maxlags=20,rotation = 45)

plt.legend()
plt.savefig('./imgs/all.png',transparent=False)

# %%
fig, ax = plt.subplots()
ax.grid(True)
plt.plot('size' , 'avg', data=tim,label="avg")
plt.plot('size' , 'max', data=tim,label="max")
plt.plot('size' , 'min', data=tim,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação tim", fontsize=16, fontweight='bold')
plt.show()
fig.savefig('./imgs/tim.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=quick,label="avg")
plt.plot('size' , 'max', data=quick,label="max")
plt.plot('size' , 'min', data=quick,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação quick", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/quick.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=merge,label="avg")
plt.plot('size' , 'max', data=merge,label="max")
plt.plot('size' , 'min', data=merge,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação merge", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/merge.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=heap,label="avg")
plt.plot('size' , 'max', data=heap,label="max")
plt.plot('size' , 'min', data=heap,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação heap", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/heap.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=selection,label="avg")
plt.plot('size' , 'max', data=selection,label="max")
plt.plot('size' , 'min', data=selection,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação selection", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/selection.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=intro,label="avg")
plt.plot('size' , 'max', data=intro,label="max")
plt.plot('size' , 'min', data=intro,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação intro", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/intro.png',transparent=False)

# %%
plt.plot('size' , 'avg', data=insertion,label="avg")
plt.plot('size' , 'max', data=insertion,label="max")
plt.plot('size' , 'min', data=insertion,label="min")

plt.xlabel("Tamanho do vetor")
plt.ylabel("Tempo (segundos)")
plt.title("Tempo de ordenação insertion", fontsize=16, fontweight='bold')
plt.legend()
plt.savefig('./imgs/insertion.png',transparent=False)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df)
# Out:
#      algorithm          size         min         max         avg
# 103        tim      1.000,00    0.002318    0.002372    0.002345
# 142  selection      1.000,00    0.081908    0.083852    0.082724
# 80       quick      1.000,00    0.002509    0.002556    0.002532
# 32       intro      1.000,00    0.004202    0.004279    0.004255
# 8         heap      1.000,00    0.004241    0.004324    0.004269
# 56       merge      1.000,00    0.002124    0.002200    0.002165
# 127  insertion      1.000,00    0.049805    0.050164    0.050001
# 44       intro  1.000.000,00   13.187386   13.249615   13.220209
# 68       merge  1.000.000,00    5.443743    5.486893    5.467670
# 20        heap  1.000.000,00   13.187898   13.282636   13.234186
# 115        tim  1.000.000,00    6.814980    6.844926    6.828607
# 48       merge         10,00    0.000075    0.000151    0.000102
# 72       quick         10,00    0.000128    0.000259    0.000159
# ...
